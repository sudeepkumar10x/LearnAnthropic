# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search", 
    "max_uses": 5,
    "allowed_domains": ["nih.gov"]
}

# %%
messages = []

add_user_message(
    messages,
    """
    Best exercise for leg muscles.
    """,
)

response = chat(
    messages,
    tools=[web_search_schema])

# %%
print(response.content)
# Out:
# [TextBlock(citations=None, text='Based on general fitness knowledge, here are some of the best exercises for leg muscles:\n\n## **Compound Exercises (work multiple leg muscles):**\n\n1. **Squats** - Often considered the king of leg exercises, squats work the quadriceps, hamstrings, glutes, and calves. Variations include barbell back squats, front squats, and goblet squats.\n\n2. **Deadlifts** - Excellent for hamstrings, glutes, and lower back, with several variations like Romanian deadlifts and sumo deadlifts.\n\n3. **Lunges** - Great for quads, hamstrings, and glutes while also improving balance. Can be done walking, stationary, or reverse.\n\n4. **Leg Press** - A machine-based exercise that effectively targets quads, hamstrings, and glutes with less stress on the lower back.\n\n## **Isolation Exercises (target specific muscles):**\n\n- **Leg Extensions** - Isolate the quadriceps\n- **Leg Curls** - Target the hamstrings\n- **Calf Raises** - Focus on calf muscles\n- **Bulgarian Split Squats** - Emphasize quads and glutes\n\n## **Best Overall Choice:**\n**Squats** are generally considered the single best exercise for overall leg development because they:\n- Work all major leg muscle groups\n- Allow for progressive overload\n- Build functional strength\n- Can be modified for all fitness levels\n\nThe "best" exercise ultimately depends on your specific goals (strength, size, endurance), fitness level, and any physical limitations. A well-rounded leg routine typically includes a mix of compound and isolation exercises.', type='text')]
