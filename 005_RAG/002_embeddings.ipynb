# %%
# Install VoyageAI lib
# %pip install voyageai python-dotenv
# Out:
# Requirement already satisfied: voyageai in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (0.2.4)
# Requirement already satisfied: python-dotenv in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (1.2.2)
# Requirement already satisfied: aiohttp<4.0,>=3.5 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from voyageai) (3.13.3)
# Requirement already satisfied: aiolimiter<2.0.0,>=1.1.0 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from voyageai) (1.2.1)
# Requirement already satisfied: numpy>=1.11 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from voyageai) (2.4.3)
# Requirement already satisfied: requests<3.0,>=2.20 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from voyageai) (2.33.0)
# Requirement already satisfied: tenacity>=8.0.1 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from voyageai) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from aiohttp<4.0,>=3.5->voyageai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from aiohttp<4.0,>=3.5->voyageai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from aiohttp<4.0,>=3.5->voyageai) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from aiohttp<4.0,>=3.5->voyageai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from aiohttp<4.0,>=3.5->voyageai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from aiohttp<4.0,>=3.5->voyageai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from aiohttp<4.0,>=3.5->voyageai) (1.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from requests<3.0,>=2.20->voyageai) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from requests<3.0,>=2.20->voyageai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from requests<3.0,>=2.20->voyageai) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages (from requests<3.0,>=2.20->voyageai) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Client Setup
from dotenv import load_dotenv
import voyageai

load_dotenv()

client = voyageai.Client()

# %%
# Chunk by section
import re

def chunk_by_section(document_text):
    pattern = r"\n## "
    return re.split(pattern, document_text)

# %%
# Embedding Generation
def generate_embedding(text, model="voyage-3-large", input_type="query"):
    result = client.embed([text], model=model, input_type=input_type)

    return result.embeddings[0]

# %%
with open("./report.md", "r") as f:
    text = f.read()

chunks = chunk_by_section(text)

generate_embedding(chunks[0])
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[14], line 6
#       2     text = f.read()
#       3
#       4 chunks = chunk_by_section(text)
#       5
# ----> 6 generate_embedding(chunks[0])
#
# Cell In[13], line 3, in generate_embedding(text, model, input_type)
#       2 def generate_embedding(text, model="voyage-3-large", input_type="query"):
# ----> 3     result = client.embed([text], model=model, input_type=input_type)
#       4
#       5     return result.embeddings[0]
#
# File c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages\voyageai\client.py:63, in Client.embed(self, texts, model, input_type, truncation)
#      55     model = voyageai.VOYAGE_EMBED_DEFAULT_MODEL
#      56     warnings.warn(
#      57         f"The `model` argument is not specified and defaults to {voyageai.VOYAGE_EMBED_DEFAULT_MODEL}. "
#      58         "It will be a required argument in the future. We recommend to specify the model when using this "
#      59         "function. Please see https://docs.voyageai.com/docs/embeddings for the list of latest models "
#      60         "provided by Voyage AI."
#      61     )
# ---> 63 for attempt in self.retry_controller:
#      64     with attempt:
#      65         response = voyageai.Embedding.create(
#      66             input=texts,
#      67             model=model,
#    (...)     70             **self._params,
#      71         )
#
# File c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages\tenacity\__init__.py:438, in BaseRetrying.__iter__(self)
#     436 retry_state = RetryCallState(self, fn=None, args=(), kwargs={})
#     437 while True:
# --> 438     do = self.iter(retry_state=retry_state)
#     439     if isinstance(do, DoAttempt):
#     440         yield AttemptManager(retry_state=retry_state)
#
# File c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     391 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     392     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393         self._add_action_func(lambda rs: rs.outcome.result())
#     394         return
#     396     if self.after is not None:
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\concurrent\futures\_base.py:443, in Future.result(self, timeout)
#     441     raise CancelledError()
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages\voyageai\client.py:65, in Client.embed(self, texts, model, input_type, truncation)
#      63 for attempt in self.retry_controller:
#      64     with attempt:
# ---> 65         response = voyageai.Embedding.create(
#      66             input=texts,
#      67             model=model,
#      68             input_type=input_type,
#      69             truncation=truncation,
#      70             **self._params,
#      71         )
#      73 result = EmbeddingsObject(response)
#      74 return result
#
# File c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages\voyageai\api_resources\embedding.py:22, in Embedding.create(cls, *args, **kwargs)
#      19 if not user_provided_encoding_format:
#      20     kwargs["encoding_format"] = "base64"
# ---> 22 response = super().create(*args, **kwargs)
#      24 # If a user specifies base64, we'll just return the encoded string.
#      25 # This is only for the default case.
#      26 if not user_provided_encoding_format:
#
# File c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages\voyageai\api_resources\api_resource.py:47, in APIResource.create(cls, api_key, api_base, request_id, request_timeout, **params)
#      34 @classmethod
#      35 def create(
#      36     cls,
#    (...)     41     **params,
#      42 ):
#      43     requestor, url, params, headers = cls.__prepare_create_request(
#      44         api_key, api_base, **params
#      45     )
# ---> 47     response = requestor.request(
#      48         "post",
#      49         url,
#      50         params=params,
#      51         headers=headers,
#      52         request_id=request_id,
#      53         request_timeout=request_timeout,
#      54     )
#      56     obj = convert_to_voyage_response(response)
#      57     return obj
#
# File c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages\voyageai\api_resources\api_requestor.py:147, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     126 def request(
#     127     self,
#     128     method,
#    (...)    135     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     136 ) -> VoyageHttpResponse:
#     137     result = self.request_raw(
#     138         method.lower(),
#     139         url,
#    (...)    145         request_timeout=request_timeout,
#     146     )
# --> 147     resp = self._interpret_response(result)
#     148     return resp
#
# File c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages\voyageai\api_resources\api_requestor.py:408, in APIRequestor._interpret_response(self, result)
#     405 def _interpret_response(self, result: requests.Response) -> VoyageHttpResponse:
#     406     """Returns the response(s) and a bool indicating whether it is a stream."""
# --> 408     return self._interpret_response_line(
#     409         result.content.decode("utf-8"),
#     410         result.status_code,
#     411         result.headers,
#     412     )
#
# File c:\Users\infsu\OneDrive\Documents\GitHub\LearnAnthropic\.venv\Lib\site-packages\voyageai\api_resources\api_requestor.py:463, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders)
#     461 resp = VoyageHttpResponse(data, rheaders)
#     462 if 400 <= rcode < 500:
# --> 463     raise self.handle_error_response(rbody, rcode, resp.data, rheaders)
#     464 return resp
#
# AuthenticationError: Provided API key is invalid.
