# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS Region Code Extractor\n\nHere's a solution to extract AWS region codes from CloudFormation template URLs:\n\n## Python Solution\n\n```python\nimport re\nfrom urllib.parse import urlparse, parse_qs\n\ndef extract_region_from_cf_url(url):\n    \"\"\"\n    Extract AWS region code from CloudFormation template URL\n    \n    Args:\n        url (str): CloudFormation URL\n        \n    Returns:\n        str: Region code (e.g., 'us-east-1') or None if not found\n    \"\"\"\n    # Parse the URL\n    parsed = urlparse(url)\n    \n    # Extract query parameters\n    params = parse_qs(parsed.query)\n    \n    # Get region parameter\n    region = params.get('region', [None])[0]\n    \n    return region\n\n\n# Alternative regex solution\ndef extract_region_regex(url):\n    \"\"\"Extract region using regex pattern\"\"\"\n    match = re.search(r'region=([a-z]{2}-[a-z]+-\\d)', url)\n    return match.group(1) if match else None\n\n\n# Test cases\ntest_urls = [\n    \"https://console.aws.amazon.com/cloudformation/home?region=us-east-1\",\n    \"https://console.aws.amazon.com/cloudformation/home?region=eu-west-1\",\n    \"https://console.aws.amazon.com/cloudformation/home?region=ap-southeast-2\",\n    \"https://console.aws.amazon.com/cloudformation/home?region=us-west-2&foo=bar\",\n]\n\nprint(\"Using urllib.parse:\")\nfor url in test_urls:\n    region = extract_region_from_cf_url(url)\n    print(f\"{url} \u2192 {region}\")\n\nprint(\"\\nUsing regex:\")\nfor url in test_urls:\n    region = extract_region_regex(url)\n    print(f\"{url} \u2192 {region}\")\n```\n\n## Output\n\n```\nUsing urllib.parse:\nhttps://console.aws.amazon.com/cloudformation/home?region=us-east-1 \u2192 us-east-1\nhttps://console.aws.amazon.com/cloudformation/home?region=eu-west-1 \u2192 eu-west-1\nhttps://console.aws.amazon.com/cloudformation/home?region=ap-southeast-2 \u2192 ap-southeast-2\nhttps://console.aws.amazon.com/cloudformation/home?region=us-west-2&foo=bar \u2192 us-west-2\n```\n\n## Recommendations\n\n- **Use `urllib.parse`** (first solution) - More robust and handles edge cases\n- **Use regex** (second solution) - Simpler if you only need quick extraction\n- Both handle multiple query parameters correctly",
#     "test_case": {
#       "task": "Extract AWS region codes from CloudFormation template URLs in the format https://console.aws.amazon.com/cloudformation/home?region=us-east-1",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution is generally solid and demonstrates good practices by recommending urllib.parse as the primary approach. The urllib.parse implementation is correct and handles the task well. However, the regex solution has a significant limitation - the pattern `[a-z]{2}-[a-z]+-\\d` doesn't match all valid AWS regions (e.g., 'ca-central-1' has 'central' not just any length). Additionally, the solution lacks error handling for edge cases. For a production AWS solution, these gaps could cause failures with non-standard inputs."
#   },
#   {
#     "output": "# AWS IAM Policy Parser - DynamoDB ARN Extractor\n\nHere's a solution to parse an AWS IAM policy and extract DynamoDB resource ARNs:\n\n```python\nimport json\nfrom typing import List\n\ndef extract_dynamodb_arns(policy: dict) -> List[str]:\n    \"\"\"\n    Extract all DynamoDB resource ARNs from an AWS IAM policy.\n    \n    Args:\n        policy: AWS IAM policy as a dictionary\n        \n    Returns:\n        List of DynamoDB ARNs found in the policy\n    \"\"\"\n    dynamodb_arns = []\n    \n    # Get the Statement array from the policy\n    statements = policy.get('Statement', [])\n    \n    if not isinstance(statements, list):\n        statements = [statements]\n    \n    for statement in statements:\n        # Get Resource field (can be string or list)\n        resources = statement.get('Resource', [])\n        \n        # Normalize to list\n        if isinstance(resources, str):\n            resources = [resources]\n        \n        # Filter for DynamoDB ARNs (case-insensitive)\n        for resource in resources:\n            if isinstance(resource, str) and 'dynamodb' in resource.lower():\n                dynamodb_arns.append(resource)\n    \n    return dynamodb_arns\n\n\n# Example Usage\nif __name__ == \"__main__\":\n    # Sample IAM policy\n    sample_policy = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"dynamodb:GetItem\",\n                \"Resource\": \"arn:aws:dynamodb:us-east-1:123456789012:table/Users\"\n            },\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"arn:aws:s3:::my-bucket/*\"\n            },\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"dynamodb:*\",\n                \"Resource\": [\n                    \"arn:aws:dynamodb:us-west-2:123456789012:table/Orders\",\n                    \"arn:aws:dynamodb:us-west-2:123456789012:table/Inventory\",\n                    \"arn:aws:ec2:us-east-1:123456789012:instance/*\"\n                ]\n            }\n        ]\n    }\n    \n    # Extract DynamoDB ARNs\n    arns = extract_dynamodb_arns(sample_policy)\n    \n    print(\"DynamoDB ARNs found:\")\n    for arn in arns:\n        print(f\"  - {arn}\")\n```\n\n**Output:**\n```\nDynamoDB ARNs found:\n  - arn:aws:dynamodb:us-east-1:123456789012:table/Users\n  - arn:aws:dynamodb:us-west-2:123456789012:table/Orders\n  - arn:aws:dynamodb:us-west-2:123456789012:table/Inventory\n```\n\n## Key Features:\n\n\u2705 **Handles multiple formats:**\n- Single resource (string)\n- Multiple resources (list)\n- Multiple statements\n\n\u2705 **Case-insensitive matching** for 'dynamodb'\n\n\u2705 **Filters out** non-DynamoDB resources\n\n\u2705 **Type-safe** with proper error handling\n\n## Advanced Version with JSON Input:\n\n```python\ndef extract_dynamodb_arns_from_json(policy_json: str) -> List[str]:\n    \"\"\"Parse JSON string and extract DynamoDB ARNs\"\"\"\n    try:\n        policy = json.loads(policy_json)\n        return extract_dynamodb_arns(policy)\n    except json.JSONDecodeError as e:\n        print(f\"Invalid JSON: {e}\")\n        return []\n\n# Usage with JSON string\npolicy_string = '''\n{\n    \"Version\": \"2012-10-17\",\n    \"Statement\": [{\n        \"Effect\": \"Allow\",\n        \"Action\": \"dynamodb:*\",\n        \"Resource\": \"arn:aws:dynamodb:*:123456789012:table/*\"\n    ",
#     "test_case": {
#       "task": "Parse an AWS IAM policy JSON object and extract all resource ARNs that contain 'dynamodb'",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution successfully solves the core task with a pragmatic approach that handles common IAM policy structures. The implementation is readable and includes good examples. However, the string-matching approach for ARN filtering is overly simplistic and could produce false positives. A regex-based approach validating proper ARN format (arn:aws:dynamodb:...) would be more robust. The incomplete advanced example and lack of NotResource handling slightly diminish the solution's completeness."
#   },
#   {
#     "output": "# AWS S3 Bucket Policy - Public Read Access\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"PublicReadGetObject\",\n      \"Effect\": \"Allow\",\n      \"Principal\": \"*\",\n      \"Action\": \"s3:GetObject\",\n      \"Resource\": \"arn:aws:s3:::your-bucket-name/*\"\n    }\n  ]\n}\n```\n\n## Explanation\n\n| Component | Description |\n|-----------|-------------|\n| **Version** | Policy language version (required, use `2012-10-17`) |\n| **Statement** | Array containing one or more policy rules |\n| **Sid** | Optional statement identifier for clarity |\n| **Effect** | `Allow` or `Deny` - permits public read access |\n| **Principal** | `\"*\"` means everyone (public access) |\n| **Action** | `s3:GetObject` allows reading/downloading objects |\n| **Resource** | `arn:aws:s3:::bucket-name/*` targets all objects in the bucket |\n\n## Important Notes \u26a0\ufe0f\n\n1. **Replace** `your-bucket-name` with your actual S3 bucket name\n2. **Security Risk**: This makes all objects publicly readable - use carefully\n3. **Block Public Access Settings**: AWS may block this unless you disable block public access settings first\n4. **Consider alternatives**: Use CloudFront, presigned URLs, or IAM roles for better security\n\n## Additional Options\n\nTo also allow listing bucket contents, add:\n```json\n{\n  \"Sid\": \"PublicListBucket\",\n  \"Effect\": \"Allow\",\n  \"Principal\": \"*\",\n  \"Action\": \"s3:ListBucket\",\n  \"Resource\": \"arn:aws:s3:::your-bucket-name\"\n}\n```",
#     "test_case": {
#       "task": "Create a JSON structure representing an AWS S3 bucket policy that allows public read access to all objects",
#       "format": "json"
#     },
#     "score": 8,
#     "reasoning": "The solution correctly implements the core requirement with syntactically valid JSON and proper IAM policy structure. The explanation is clear and the security warnings are appropriately prominent. However, it could be more complete by addressing the interplay with Block Public Access settings (a common point of confusion) and acknowledging edge cases like versioning. The overall guidance quality is high with good emphasis on security considerations."
#   }
# ]
