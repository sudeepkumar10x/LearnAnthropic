# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 5.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport sys\nimport re\n\n# Read the CloudFormation template from stdin or as argument\ntry:\n    # Attempt to read from stdin or use the provided argument\n    if len(sys.argv) > 1:\n        with open(sys.argv[1], 'r') as f:\n            template_str = f.read()\n    else:\n        template_str = sys.stdin.read()\n    \n    # Try to parse as JSON first, then YAML\n    try:\n        template = json.loads(template_str)\n    except json.JSONDecodeError:\n        try:\n            import yaml\n            template = yaml.safe_load(template_str)\n        except:\n            # Fallback to simple regex for both JSON and YAML\n            pattern = r'\"([^\"]+)\"\\s*:\\s*{\\s*\"Type\"\\s*:\\s*\"AWS::S3::Bucket\"'\n            matches = re.findall(pattern, template_str, re.MULTILINE)\n            for match in matches:\n                print(match)\n            sys.exit(0)\n    \n    # Extract S3 bucket resources\n    if isinstance(template, dict) and 'Resources' in template:\n        resources = template.get('Resources', {})\n        for logical_id, resource_def in resources.items():\n            if isinstance(resource_def, dict) and resource_def.get('Type') == 'AWS::S3::Bucket':\n                print(logical_id)\nexcept Exception as e:\n    # Fallback regex pattern for raw template\n    pattern = r'\"([^\"]+)\"\\s*:\\s*{\\s*\"Type\"\\s*:\\s*\"AWS::S3::Bucket\"'\n    matches = re.findall(pattern, template_str, re.MULTILINE)\n    for match in matches:\n        print(match)\n",
#     "test_case": {
#       "task": "Parse an AWS CloudFormation template and extract all resource logical IDs that are of type AWS::S3::Bucket",
#       "format": "python",
#       "solution_criteria": "Function should return a list of logical IDs for all S3 buckets defined in a CloudFormation template dictionary. Should handle nested structures and return an empty list if no S3 buckets are found."
#     },
#     "score": 7.5,
#     "reasoning": "The solution demonstrates good defensive programming with multiple parsing strategies, but fundamentally misaligns with the stated requirement to 'return a list of logical IDs'. It's designed as a CLI tool with print-based output rather than a reusable function. The regex fallback, while well-intentioned, is brittle and could miss valid resources or match invalid patterns. For a proper AWS code review, this would need refactoring to be a proper function returning a list, along with tighter error handling."
#   },
#   {
#     "output": "\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that processes S3 events, with environment variables for log level and SNS topic ARN",
#       "format": "json",
#       "solution_criteria": "JSON object should include function name, runtime, handler, role ARN placeholder, environment variables section with LOG_LEVEL and SNS_TOPIC_ARN keys, and timeout/memory settings appropriate for S3 processing."
#     },
#     "score": 0.5,
#     "reasoning": "The solution provided is blank/empty. There is no JSON configuration object to review. A complete AWS Lambda configuration for S3 event processing with the specified environment variables (LOG_LEVEL and SNS_TOPIC_ARN) is entirely absent. No evaluation against the stated criteria is possible."
#   },
#   {
#     "output": "\n^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9+=,.@_/-]+$\n",
#     "test_case": {
#       "task": "Create a regular expression to validate AWS IAM role ARN format (arn:aws:iam::account-id:role/role-name)",
#       "format": "regex",
#       "solution_criteria": "Regex should match valid IAM role ARNs, capture the account ID and role name, reject invalid formats, and handle role names with hyphens and forward slashes."
#     },
#     "score": 8.0,
#     "reasoning": "The regex validates the basic format correctly but fails the capture group requirement explicitly stated in the criteria. The character class is overly permissive - AWS IAM role names only allow alphanumeric characters, hyphens, and underscores, with forward slashes only as path separators. The solution needs modification to include capturing groups: ^arn:aws:iam::(\\d{12}):role/([a-zA-Z0-9+=,.@_-]+)$ would capture both components, though the character class should still be refined to match AWS specifications more accurately."
#   }
# ]
