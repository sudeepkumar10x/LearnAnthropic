# %%
# load env variables from .env file
from dotenv import load_dotenv
load_dotenv()

# create an instance of the Anthropic client and specify the model to use
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
# Define helper functions to read latest text/ response & append it into message to 
# send it to the model and print the response

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None):
    kwargs = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages
    }
    
    if system:
        kwargs["system"] = system
    
    message = client.messages.create(**kwargs)
    
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "what is 1*100?")

# Without system prompt
answer_without_system = chat(messages)

# With system prompt
system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
answer = chat(messages, system=system)

# %%
print(answer_without_system)
# Out:
# 1 * 100 = 100

# %%
print(answer)
# Out:
# I can see you're working with multiplication! Let me guide you through this step by step.
#
# When you multiply any number by 1, what do you think happens to that number?
#
# Think about it this way: if you have 1 group of something, how many of that something do you have in total?
#
# Can you tell me what you think 1 × 100 equals based on this idea?

# %% [markdown]
# # Exercise
#
# ## First we will try to see how largs is the response without system prompt

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Write a python function that checks strings for duplicate characters")

# Without system prompt
answer_without_system = chat(messages)

print(answer_without_system)
# Out:
# Here are several Python functions to check strings for duplicate characters, depending on your specific needs:
#
# ## Method 1: Simple Boolean Check (Most Common)
# ```python
# def has_duplicates(s):
#     """
#     Check if a string contains duplicate characters.
#
#     Args:
#         s (str): Input string
#
#     Returns:
#         bool: True if duplicates exist, False otherwise
#     """
#     return len(s) != len(set(s))
#
# # Example usage
# print(has_duplicates("hello"))     # True (duplicate 'l')
# print(has_duplicates("world"))     # True (duplicate 'r', wait no... False!)
# print(has_duplicates("python"))    # False
# print(has_duplicates("programming"))  # True (duplicate 'r', 'm', 'g')
# ```
#
# ## Method 2: Find Which Characters Are Duplicated
# ```python
# def find_duplicates(s):
#     """
#     Find which characters appear more than once in a string.
#
#     Args:
#         s (str): Input string
#
#     Returns:
# ...

# %% [markdown]
# ## To truncate and limit the output, we will use system prompt

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Write a python function that checks strings for duplicate characters")

# Without system prompt
answer = chat(messages, system="You are a python engineer who writes very concise code.")

print(answer)
# Out:
# ```python
# def has_duplicates(s):
#     return len(s) != len(set(s))
# ```
#
# This function converts the string to a set (which removes duplicates) and compares the lengths. If they differ, there were duplicate characters.
